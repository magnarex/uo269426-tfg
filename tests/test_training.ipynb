# %% [markdown]
# # Prueba de Entrenamiento

# %% [markdown]
# ## Paquetes

# %%
import numpy as np
import re
import pandas as pd

import os
import sys
import inspect

parentdir = r'F:\Clase\Universidad\04 - Cuarto\TFG\DQM-DC NMF'
sys.path.append(parentdir)


from utils.df_utils import *
from utils.plot_utils import *

pd.set_option('colheader_justify', 'center')

import functools

import matplotlib.pyplot as plt
# %matplotlib qt
plt.rcParams['figure.dpi'] = 300
plt.rcParams["figure.figsize"] = (3,2)
plt.rcParams.update({'font.size': 6})

import datetime
import logging
timestamp = datetime.datetime.utcnow().strftime('%Y%m%d')
filename=f'{parentdir}/tmp/read_data_{timestamp}.log'
formatter = logging.Formatter('[%(asctime)s] %(name)s {%(filename)s:%(lineno)d} %(levelname)s - %(message)s')

file_handler = logging.FileHandler(filename=filename, mode='a+')
file_handler.setLevel(logging.DEBUG)
file_handler.setFormatter(formatter)

stream_handler = logging.StreamHandler(sys.stdout)
stream_handler.setLevel(logging.INFO)

# The handlers have to be at a root level since they are the final output
logging.basicConfig(
    level=logging.DEBUG, 
    format='[{%(filename)s:%(lineno)d} %(levelname)s - %(message)s',
    handlers=[
        file_handler,
        stream_handler
    ]
)

logging.info(f'\n\n\nRun at {datetime.datetime.utcnow().strftime("%H-%M-%S")}')
# Out:
# [{199696191.py:49} INFO -
#
#
# Run at 10-55-06

# %% [markdown]
# ## Código

# %% [markdown]
# ### Obtención de los datos

# %%
names = np.array([f.split('.')[0] for f in os.listdir(f'{parentdir}/data/csv') if os.path.isfile(os.path.join(f'{parentdir}/data/csv', f))])

cols =['chi2','eta','phi','pt']
inds = ['A','B','C','D']

names_df  =pd.DataFrame(names.reshape(4,4).T, index=inds,columns=cols)
df_pprint(names_df)
# Out:
# <style type="text/css">
# #T_454d2 th {
#   text-align: center;
# }
# #T_454d2_row0_col0, #T_454d2_row0_col1, #T_454d2_row0_col2, #T_454d2_row0_col3, #T_454d2_row1_col0, #T_454d2_row1_col1, #T_454d2_row1_col2, #T_454d2_row1_col3, #T_454d2_row2_col0, #T_454d2_row2_col1, #T_454d2_row2_col2, #T_454d2_row2_col3 {
#   text-align: center;
#   float_format: <built-in method format of str object at 0x00000258DC55D6F0>;
# }
# </style>
# <table id="T_454d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_454d2_level0_col0" class="col_heading level0 col0" >chi2</th>
#       <th id="T_454d2_level0_col1" class="col_heading level0 col1" >eta</th>
#       <th id="T_454d2_level0_col2" class="col_heading level0 col2" >phi</th>
#       <th id="T_454d2_level0_col3" class="col_heading level0 col3" >pt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_454d2_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_454d2_row0_col0" class="data row0 col0" >GlbMuon_Glb_chi2OverDf_MuonCert_Labeled_UL2018A_Reduced</td>
#       <td id="T_454d2_row0_col1" class="data row0 col1" >GlbMuon_Glb_eta_MuonCert_Labeled_UL2018A_Reduced</td>
#       <td id="T_454d2_row0_col2" class="data row0 col2" >GlbMuon_Glb_phi_MuonCert_Labeled_UL2018A_Reduced</td>
#       <td id="T_454d2_row0_col3" class="data row0 col3" >GlbMuon_Glb_pt_MuonCert_Labeled_UL2018A_Reduced</td>
#     </tr>
#     <tr>
#       <th id="T_454d2_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_454d2_row1_col0" class="data row1 col0" >GlbMuon_Glb_chi2OverDf_MuonCert_Labeled_UL2018B_Reduced</td>
#       <td id="T_454d2_row1_col1" class="data row1 col1" >GlbMuon_Glb_eta_MuonCert_Labeled_UL2018B_Reduced</td>
#       <td id="T_454d2_row1_col2" class="data row1 col2" >GlbMuon_Glb_phi_MuonCert_Labeled_UL2018B_Reduced</td>
#       <td id="T_454d2_row1_col3" class="data row1 col3" >GlbMuon_Glb_pt_MuonCert_Labeled_UL2018B_Reduced</td>
#     </tr>
#     <tr>
#       <th id="T_454d2_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_454d2_row2_col0" class="data row2 col0" >GlbMuon_Glb_chi2OverDf_MuonCert_Labeled_UL2018C_Reduced</td>
#       <td id="T_454d2_row2_col1" class="data row2 col1" >GlbMuon_Glb_eta_MuonCert_Labeled_UL2018C_Reduced</td>
#       <td id="T_454d2_row2_col2" class="data row2 col2" >GlbMuon_Glb_phi_MuonCert_Labeled_UL2018C_Reduced</td>
#       <td id="T_454d2_row2_col3" class="data row2 col3" >GlbMuon_Glb_pt_MuonCert_Labeled_UL2018C_Reduced</td>
#     </tr>
#   </tbody>
# </table>

# %%
observable = 'eta'
file = pd.read_csv(f'{parentdir}/data/csv/'+names_df.at['A',observable]+'.csv')

file['histo'] = file['histo'].apply(str2arr)

df_pprint(file)
# Out:
# <style type="text/css">
# #T_8c845 th {
#   text-align: center;
# }
# #T_8c845_row0_col0, #T_8c845_row0_col1, #T_8c845_row0_col2, #T_8c845_row0_col3, #T_8c845_row0_col4, #T_8c845_row0_col5, #T_8c845_row0_col6, #T_8c845_row0_col7, #T_8c845_row0_col8, #T_8c845_row1_col0, #T_8c845_row1_col1, #T_8c845_row1_col2, #T_8c845_row1_col3, #T_8c845_row1_col4, #T_8c845_row1_col5, #T_8c845_row1_col6, #T_8c845_row1_col7, #T_8c845_row1_col8, #T_8c845_row2_col0, #T_8c845_row2_col1, #T_8c845_row2_col2, #T_8c845_row2_col3, #T_8c845_row2_col4, #T_8c845_row2_col5, #T_8c845_row2_col6, #T_8c845_row2_col7, #T_8c845_row2_col8 {
#   text-align: center;
#   float_format: <built-in method format of str object at 0x00000258DC55D6F0>;
# }
# </style>
# <table id="T_8c845">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c845_level0_col0" class="col_heading level0 col0" >fromrun</th>
#       <th id="T_8c845_level0_col1" class="col_heading level0 col1" >fromlumi</th>
#       <th id="T_8c845_level0_col2" class="col_heading level0 col2" >labels</th>
#       <th id="T_8c845_level0_col3" class="col_heading level0 col3" >hname</th>
#       <th id="T_8c845_level0_col4" class="col_heading level0 col4" >histo</th>
#       <th id="T_8c845_level0_col5" class="col_heading level0 col5" >entries</th>
#       <th id="T_8c845_level0_col6" class="col_heading level0 col6" >Xbins</th>
#       <th id="T_8c845_level0_col7" class="col_heading level0 col7" >Xmin</th>
#       <th id="T_8c845_level0_col8" class="col_heading level0 col8" >Xmax</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c845_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c845_row0_col0" class="data row0 col0" >315489</td>
#       <td id="T_8c845_row0_col1" class="data row0 col1" >707</td>
#       <td id="T_8c845_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_8c845_row0_col3" class="data row0 col3" >GlbMuon_Glb_eta</td>
#       <td id="T_8c845_row0_col4" class="data row0 col4" >[ 0.  0.  0.  0.  2.  0.  3.  2.  3. 10. 33. 35. 44. 36. 47. 43. 35. 45.
#  47. 38. 38. 39. 34. 40. 35. 39. 37. 38. 47. 36. 41. 26. 38. 33. 34. 32.
#  26. 29. 31. 34. 44. 39. 42. 38. 29. 23. 29. 29. 31. 31. 41. 29. 29. 27.
#  28. 30. 45. 40. 38. 32. 37. 35. 30. 33. 35. 37. 32. 36. 39. 28. 32. 33.
#  42. 58. 38. 47. 28. 57. 34. 40. 47. 48. 56. 47. 47. 54. 37. 34. 49. 44.
#  12. 10.  3.  1.  0.  2.  0.  0.  0.  0.]</td>
#       <td id="T_8c845_row0_col5" class="data row0 col5" >3046.000000</td>
#       <td id="T_8c845_row0_col6" class="data row0 col6" >100</td>
#       <td id="T_8c845_row0_col7" class="data row0 col7" >-3.000000</td>
#       <td id="T_8c845_row0_col8" class="data row0 col8" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8c845_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c845_row1_col0" class="data row1 col0" >316060</td>
#       <td id="T_8c845_row1_col1" class="data row1 col1" >547</td>
#       <td id="T_8c845_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_8c845_row1_col3" class="data row1 col3" >GlbMuon_Glb_eta</td>
#       <td id="T_8c845_row1_col4" class="data row1 col4" >[ 0.  0.  0.  1.  1.  2.  3.  7.  6. 18. 62. 66. 56. 55. 64. 55. 59. 46.
#  65. 45. 64. 50. 66. 53. 47. 66. 59. 60. 51. 52. 46. 49. 44. 59. 49. 56.
#  53. 48. 65. 52. 62. 54. 48. 48. 61. 42. 43. 57. 56. 51. 59. 46. 55. 48.
#  38. 39. 53. 59. 45. 41. 40. 52. 55. 44. 47. 48. 54. 49. 54. 63. 40. 60.
#  63. 62. 53. 62. 59. 57. 60. 46. 48. 74. 67. 78. 76. 56. 56. 70. 48. 40.
#  18.  9.  6.  4.  0.  0.  0.  0.  0.  0.]</td>
#       <td id="T_8c845_row1_col5" class="data row1 col5" >4423.000000</td>
#       <td id="T_8c845_row1_col6" class="data row1 col6" >100</td>
#       <td id="T_8c845_row1_col7" class="data row1 col7" >-3.000000</td>
#       <td id="T_8c845_row1_col8" class="data row1 col8" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8c845_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c845_row2_col0" class="data row2 col0" >316060</td>
#       <td id="T_8c845_row2_col1" class="data row2 col1" >548</td>
#       <td id="T_8c845_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_8c845_row2_col3" class="data row2 col3" >GlbMuon_Glb_eta</td>
#       <td id="T_8c845_row2_col4" class="data row2 col4" >[ 0.  0.  0.  1.  1.  2.  4.  2.  6. 22. 44. 63. 66. 48. 69. 67. 42. 50.
#  39. 59. 57. 52. 66. 54. 60. 50. 54. 61. 61. 64. 55. 51. 56. 55. 51. 34.
#  61. 52. 55. 46. 64. 52. 48. 60. 55. 47. 40. 54. 80. 60. 53. 73. 52. 49.
#  50. 54. 62. 62. 55. 48. 67. 58. 65. 52. 59. 55. 47. 52. 47. 54. 57. 54.
#  52. 54. 64. 57. 65. 68. 52. 67. 50. 76. 73. 73. 63. 67. 55. 75. 62. 50.
#  22. 14.  6.  6.  4.  2.  0.  0.  0.  0.]</td>
#       <td id="T_8c845_row2_col5" class="data row2 col5" >4642.000000</td>
#       <td id="T_8c845_row2_col6" class="data row2 col6" >100</td>
#       <td id="T_8c845_row2_col7" class="data row2 col7" >-3.000000</td>
#       <td id="T_8c845_row2_col8" class="data row2 col8" >3.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Entrenamiento

# %% [markdown]
# Importamos los paquetes necesarios para entrenar la red

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.feature_extraction import text

# %% [markdown]
# Tratamos los datos y nos aseguramos de que se hayan separado bien

# %%
file = file[file.entries != 0]

all = np.stack(file['histo'].to_numpy())/np.c_[file['entries'].to_numpy()]
# nonzero_id = np.where(entries!=0)[0]

# all = all[nonzero_id]
# entries = entries[nonzero_id]




# print(all[:3])
goodness = np.stack(file['labels'].values)
# print(goodness)

good = all[goodness==True]
bad = all[goodness==False]

ratio_gb = len(good)/len(bad); print(ratio_gb) #aprox 80 buenas por cada mala
print(f'{len(bad)}+{len(good)} == {len(bad)+len(good)} == {len(all)}')
# Out:
# 191.32958801498128
# 267+51085 == 51352 == 51352

# %% [markdown]
# Damos forma a los datos

# %%
span = np.linspace(file['Xmin'].values[0],file['Xmax'].values[0],num=file['Xbins'].values[0])
V_matrix = pd.DataFrame(all)

df_pprint(V_matrix)
# Out:
# <style type="text/css">
# #T_e762d th {
#   text-align: center;
# }
# #T_e762d_row0_col0, #T_e762d_row0_col1, #T_e762d_row0_col2, #T_e762d_row0_col3, #T_e762d_row0_col4, #T_e762d_row0_col5, #T_e762d_row0_col6, #T_e762d_row0_col7, #T_e762d_row0_col8, #T_e762d_row0_col9, #T_e762d_row0_col10, #T_e762d_row0_col11, #T_e762d_row0_col12, #T_e762d_row0_col13, #T_e762d_row0_col14, #T_e762d_row0_col15, #T_e762d_row0_col16, #T_e762d_row0_col17, #T_e762d_row0_col18, #T_e762d_row0_col19, #T_e762d_row0_col20, #T_e762d_row0_col21, #T_e762d_row0_col22, #T_e762d_row0_col23, #T_e762d_row0_col24, #T_e762d_row0_col25, #T_e762d_row0_col26, #T_e762d_row0_col27, #T_e762d_row0_col28, #T_e762d_row0_col29, #T_e762d_row0_col30, #T_e762d_row0_col31, #T_e762d_row0_col32, #T_e762d_row0_col33, #T_e762d_row0_col34, #T_e762d_row0_col35, #T_e762d_row0_col36, #T_e762d_row0_col37, #T_e762d_row0_col38, #T_e762d_row0_col39, #T_e762d_row0_col40, #T_e762d_row0_col41, #T_e762d_row0_col42, #T_e762d_row0_col43, #T_e762d_row0_col44, #T_e762d_row0_col45, #T_e762d_row0_col46, #T_e762d_row0_col47, #T_e762d_row0_col48, #T_e762d_row0_col49, #T_e762d_row0_col50, #T_e762d_row0_col51, #T_e762d_row0_col52, #T_e762d_row0_col53, #T_e762d_row0_col54, #T_e762d_row0_col55, #T_e762d_row0_col56, #T_e762d_row0_col57, #T_e762d_row0_col58, #T_e762d_row0_col59, #T_e762d_row0_col60, #T_e762d_row0_col61, #T_e762d_row0_col62, #T_e762d_row0_col63, #T_e762d_row0_col64, #T_e762d_row0_col65, #T_e762d_row0_col66, #T_e762d_row0_col67, #T_e762d_row0_col68, #T_e762d_row0_col69, #T_e762d_row0_col70, #T_e762d_row0_col71, #T_e762d_row0_col72, #T_e762d_row0_col73, #T_e762d_row0_col74, #T_e762d_row0_col75, #T_e762d_row0_col76, #T_e762d_row0_col77, #T_e762d_row0_col78, #T_e762d_row0_col79, #T_e762d_row0_col80, #T_e762d_row0_col81, #T_e762d_row0_col82, #T_e762d_row0_col83, #T_e762d_row0_col84, #T_e762d_row0_col85, #T_e762d_row0_col86, #T_e762d_row0_col87, #T_e762d_row0_col88, #T_e762d_row0_col89, #T_e762d_row0_col90, #T_e762d_row0_col91, #T_e762d_row0_col92, #T_e762d_row0_col93, #T_e762d_row0_col94, #T_e762d_row0_col95, #T_e762d_row0_col96, #T_e762d_row0_col97, #T_e762d_row0_col98, #T_e762d_row0_col99, #T_e762d_row1_col0, #T_e762d_row1_col1, #T_e762d_row1_col2, #T_e762d_row1_col3, #T_e762d_row1_col4, #T_e762d_row1_col5, #T_e762d_row1_col6, #T_e762d_row1_col7, #T_e762d_row1_col8, #T_e762d_row1_col9, #T_e762d_row1_col10, #T_e762d_row1_col11, #T_e762d_row1_col12, #T_e762d_row1_col13, #T_e762d_row1_col14, #T_e762d_row1_col15, #T_e762d_row1_col16, #T_e762d_row1_col17, #T_e762d_row1_col18, #T_e762d_row1_col19, #T_e762d_row1_col20, #T_e762d_row1_col21, #T_e762d_row1_col22, #T_e762d_row1_col23, #T_e762d_row1_col24, #T_e762d_row1_col25, #T_e762d_row1_col26, #T_e762d_row1_col27, #T_e762d_row1_col28, #T_e762d_row1_col29, #T_e762d_row1_col30, #T_e762d_row1_col31, #T_e762d_row1_col32, #T_e762d_row1_col33, #T_e762d_row1_col34, #T_e762d_row1_col35, #T_e762d_row1_col36, #T_e762d_row1_col37, #T_e762d_row1_col38, #T_e762d_row1_col39, #T_e762d_row1_col40, #T_e762d_row1_col41, #T_e762d_row1_col42, #T_e762d_row1_col43, #T_e762d_row1_col44, #T_e762d_row1_col45, #T_e762d_row1_col46, #T_e762d_row1_col47, #T_e762d_row1_col48, #T_e762d_row1_col49, #T_e762d_row1_col50, #T_e762d_row1_col51, #T_e762d_row1_col52, #T_e762d_row1_col53, #T_e762d_row1_col54, #T_e762d_row1_col55, #T_e762d_row1_col56, #T_e762d_row1_col57, #T_e762d_row1_col58, #T_e762d_row1_col59, #T_e762d_row1_col60, #T_e762d_row1_col61, #T_e762d_row1_col62, #T_e762d_row1_col63, #T_e762d_row1_col64, #T_e762d_row1_col65, #T_e762d_row1_col66, #T_e762d_row1_col67, #T_e762d_row1_col68, #T_e762d_row1_col69, #T_e762d_row1_col70, #T_e762d_row1_col71, #T_e762d_row1_col72, #T_e762d_row1_col73, #T_e762d_row1_col74, #T_e762d_row1_col75, #T_e762d_row1_col76, #T_e762d_row1_col77, #T_e762d_row1_col78, #T_e762d_row1_col79, #T_e762d_row1_col80, #T_e762d_row1_col81, #T_e762d_row1_col82, #T_e762d_row1_col83, #T_e762d_row1_col84, #T_e762d_row1_col85, #T_e762d_row1_col86, #T_e762d_row1_col87, #T_e762d_row1_col88, #T_e762d_row1_col89, #T_e762d_row1_col90, #T_e762d_ ...
#   text-align: center;
#   float_format: <built-in method format of str object at 0x00000258DC55D6F0>;
# }
# </style>
# <table id="T_e762d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e762d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e762d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e762d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e762d_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_e762d_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_e762d_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_e762d_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_e762d_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_e762d_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_e762d_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_e762d_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_e762d_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_e762d_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_e762d_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_e762d_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_e762d_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_e762d_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_e762d_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_e762d_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_e762

# %% [markdown]
# Elegimos el número de vectores

# %%
N = 6

# %% [markdown]
# Entrenamos el modelo

# %%
nmf_model = NMF(N,max_iter=10000)
# Learn an NMF model for given Document Term Matrix 'V' 
# Extract the document-topic matrix 'W'
W = nmf_model.fit_transform(V_matrix)
# Extract top words from the topic-term matrix 'H'
# Out:
# d:\Anaconda\envs\DQM-DC_NMF\lib\site-packages\sklearn\decomposition\_nmf.py:289: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(

# %% [markdown]
# Representamos las componentes y las guardamos.

# %%
components = nmf_model.components_
# print(components.dtype)
# print(span.dtype)

titles = [f'Component{str(i).zfill(2)}' for i in range(N)]

for i in range(components.shape[0]):
    histo = components[i]
    fig, ax = plt.subplots(1,1)
    fig.suptitle(titles[i])
    # _ = ax.bar(span,histo,align='edge')
    _ = ax.step(span,histo,where='mid',linewidth=0.3)
    ax.set_xlim(0,10)
    try:
        plt.savefig(f'../graphs/test_nmf_{observable}/N={N}/{titles[i].lower()}.jpeg')
    except FileNotFoundError:
        os.makedirs(f'../graphs/test_nmf_{observable}/N={N}/')
        plt.savefig(f'../graphs/test_nmf_{observable}/N={N}/{titles[i].lower()}.jpeg')
    
    print(f'Imagen guardada en ../graphs/test_nmf_{observable}/N={N}/{titles[i].lower()}.jpeg')
    plt.close()

# df_pprint(components)
# plotnsave_hist()
# Out:
# Imagen guardada en ../graphs/test_nmf_eta/N=6/component00.jpeg
# Imagen guardada en ../graphs/test_nmf_eta/N=6/component01.jpeg
# Imagen guardada en ../graphs/test_nmf_eta/N=6/component02.jpeg
# Imagen guardada en ../graphs/test_nmf_eta/N=6/component03.jpeg
# Imagen guardada en ../graphs/test_nmf_eta/N=6/component04.jpeg
# Imagen guardada en ../graphs/test_nmf_eta/N=6/component05.jpeg

# %%
plt.plot(W[good[0]],'-r')
plt.plot(W[bad[0]],'-b')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# D:\Users\M\AppData\Local\Temp/ipykernel_12860/1097308362.py in <module>
# ----> 1 plt.plot(W[good[0]],'-r')
#       2 plt.plot(W[bad[0]],'-b')
#
# IndexError: arrays used as indices must be of integer (or boolean) type
